# %%
import pandas as pd
from datetime import time
from sys import path

path.append('/Users/suesun/Project/tianchi/kdd-cup')

# %%
# training set
df_links = pd.read_csv("../../dataSets/training/links (table 3).csv")
df_routes = pd.read_csv("../../dataSets/training/routes (table 4).csv")
df_trajectories = pd.read_csv("../../dataSets/training/trajectories(table 5)_training.csv")
df_volume = pd.read_csv("../../dataSets/training/volume(table 6)_training.csv")
df_weather = pd.read_csv("../../dataSets/training/weather (table 7)_training.csv")

# Tesing set 
df_trajectories_test = pd.read_csv("../../dataSets/testing_phase1/trajectories(table 5)_test1.csv")
df_volume_test = pd.read_csv("../../dataSets/testing_phase1/volume(table 6)_test1.csv")
df_weather_test = pd.read_csv("../../dataSets/testing_phase1/weather (table 7)_test1.csv")

# %%
df_trajectories.head(20)
# Out:
#    intersection_id  tollgate_id  vehicle_id        starting_time  \
# 0                B            3     1065642  2016-07-19 00:14:24
# 1                B            3     1047198  2016-07-19 00:35:56
# 2                B            1     1086390  2016-07-19 00:37:15
# 3                A            2     1071181  2016-07-19 00:37:59
# 4                B            1     1065807  2016-07-19 00:56:21
# 5                C            3     1072812  2016-07-19 00:56:31
# 6                B            1     1014648  2016-07-19 01:26:03
# 7                A            2     1063919  2016-07-19 01:36:04
# 8                A            3     1064408  2016-07-19 01:36:20
# 9                C            1     1056529  2016-07-19 01:36:28
# 10               A            2     1002179  2016-07-19 01:38:48
# 11               B            3     1056879  2016-07-19 01:40:40
# 12               A            2     1004088  2016-07-19 01:42:22
# ...

# %%
df_links.head(100) # show all
# Out:
#     link_id  length  width  lanes   in_top  out_top  lane_width
# 0       100      58      3      1      105      111           3
# 1       101      84      3      1      116      121           3
# 2       102     131      9      3      115      109           3
# 3       103      23     12      4      111  122,116           3
# 4       104     293      9      3      109      112           3
# 5       105      78      6      2      NaN      100           3
# 6       106      15      3      1      121      113           3
# 7       107      34      9      3      123      108           3
# 8       108      40      9      3      107  119,120           3
# 9       109     135      9      3      102      104           3
# 10      110     109      9      3      NaN      123           3
# 11      111     121     12      4  100,112      103           3
# 12      112     199      9      3      104      111           3
# 13      113     144      6      2      106      NaN           3
# ...

# %%
df_routes.head(100) # show all
# Out:
#   intersection_id  tollgate_id  \
# 0               A            2
# 1               A            3
# 2               B            1
# 3               B            3
# 4               C            1
# 5               C            3
#
#                                           link_seq
# 0                          110,123,107,108,120,117
# 1                  110,123,107,108,119,114,118,122
# 2              105,100,111,103,116,101,121,106,113
# 3                              105,100,111,103,122
# 4  115,102,109,104,112,111,103,116,101,121,106,113
# 5                  115,102,109,104,112,111,103,122

# %%
df_volume.head()
# Out:
#                   time  tollgate_id  direction  vehicle_model  has_etc  \
# 0  2016-09-19 23:09:25            2          0              1        0
# 1  2016-09-19 23:11:53            2          0              1        0
# 2  2016-09-19 23:13:54            2          0              1        0
# 3  2016-09-19 23:17:48            1          0              1        1
# 4  2016-09-19 23:16:07            2          0              1        0
#
#    vehicle_type
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN

# %%
df_weather.head(20)
# Out:
#           date  hour  pressure  sea_pressure  wind_direction  wind_speed  \
# 0   2016-07-01     0    1000.4        1005.3           225.0         2.1
# 1   2016-07-01     3    1000.5        1005.3           187.0         2.7
# 2   2016-07-01     6     998.9        1003.7           212.0         2.9
# 3   2016-07-01     9     998.7        1003.5           244.0         2.7
# 4   2016-07-01    12     999.7        1004.5           222.0         1.3
# 5   2016-07-01    15    1000.0        1004.8           102.0         1.6
# 6   2016-07-01    18     998.8        1003.6           202.0         1.9
# 7   2016-07-01    21    1000.2        1005.0           334.0         2.2
# 8   2016-07-02     0    1001.6        1006.4           315.0         1.8
# 9   2016-07-02     3    1002.4        1007.2            46.0         3.2
# 10  2016-07-02     6    1001.3        1006.2            37.0         2.2
# 11  2016-07-02     9    1001.9        1006.8           345.0         2.4
# ...

# %%
df_weather_update = pd.read_csv("../../dataSets/training/weather (table 7)_training_update.csv")

# %%
df_weather_update.head(10)
# Out:
#          date  hour  pressure  sea_pressure  wind_direction  wind_speed  \
# 0  2016-07-01     0    1000.4        1005.3           225.0         2.1
# 1  2016-07-01     3    1000.5        1005.3           187.0         2.7
# 2  2016-07-01     6     998.9        1003.7           212.0         2.9
# 3  2016-07-01     9     998.7        1003.5           244.0         2.7
# 4  2016-07-01    12     999.7        1004.5           222.0         1.3
# 5  2016-07-01    15    1000.0        1004.8           102.0         1.6
# 6  2016-07-01    18     998.8        1003.6           202.0         1.9
# 7  2016-07-01    21    1000.2        1005.0           334.0         2.2
# 8  2016-07-02     0    1001.6        1006.4           315.0         1.8
# 9  2016-07-02     3    1002.4        1007.2            46.0         3.2
#
#    temperature  rel_humidity  precipitation
# 0         26.4          94.0            0.0
# 1         29.0          76.0            0.0
# ...

# %%
df_weather.head(10)
# Out:
#          date  hour  pressure  sea_pressure  wind_direction  wind_speed  \
# 0  2016-07-01     0    1000.4        1005.3           225.0         2.1
# 1  2016-07-01     3    1000.5        1005.3           187.0         2.7
# 2  2016-07-01     6     998.9        1003.7           212.0         2.9
# 3  2016-07-01     9     998.7        1003.5           244.0         2.7
# 4  2016-07-01    12     999.7        1004.5           222.0         1.3
# 5  2016-07-01    15    1000.0        1004.8           102.0         1.6
# 6  2016-07-01    18     998.8        1003.6           202.0         1.9
# 7  2016-07-01    21    1000.2        1005.0           334.0         2.2
# 8  2016-07-02     0    1001.6        1006.4           315.0         1.8
# 9  2016-07-02     3    1002.4        1007.2            46.0         3.2
#
#    temperature  rel_humidity  precipitation
# 0         26.4          94.0            0.0
# 1         29.0          76.0            0.0
# ...

# %%
df_trajectories_test.head()
# Out:
#   intersection_id  tollgate_id  vehicle_id        starting_time  \
# 0               A            2     1026631  2016-10-18 06:00:14
# 1               C            3     1017312  2016-10-18 06:00:28
# 2               A            2     1044671  2016-10-18 06:03:07
# 3               A            3     1000017  2016-10-18 06:04:37
# 4               A            2     1002850  2016-10-18 06:10:17
#
#                                           travel_seq  travel_time
# 0  110#2016-10-18 06:00:14#7.65;123#2016-10-18 06...        27.54
# 1  115#2016-10-18 06:00:28#9.35;102#2016-10-18 06...       139.53
# 2  110#2016-10-18 06:03:07#7.22;123#2016-10-18 06...        26.01
# 3  110#2016-10-18 06:04:37#7.39;123#2016-10-18 06...        78.40
# 4  110#2016-10-18 06:10:17#14.33;123#2016-10-18 0...        71.00

# %%
df_weather_test.head()
# Out:
#          date  hour  pressure  sea_pressure  wind_direction  wind_speed  \
# 0  2016-10-18     0    1015.2        1020.3            62.0         2.1
# 1  2016-10-18     3    1014.5        1019.5            37.0         2.5
# 2  2016-10-18     6    1012.5        1017.5           128.0         1.6
# 3  2016-10-18     9    1013.0        1018.0           205.0         0.6
# 4  2016-10-18    12    1013.8        1018.8           106.0         1.5
#
#    temperature  rel_humidity  precipitation
# 0         20.5          87.0            0.0
# 1         23.3          73.0            0.0
# 2         23.4          73.0            0.0
# 3         20.9          94.0            1.8
# 4         20.5          94.0            0.5

# %%
df_volume_test.head()
# Out:
#                   time  tollgate_id  direction  vehicle_model  has_etc  \
# 0  2016-10-18 07:59:04            2          0              1        1
# 1  2016-10-18 07:59:31            2          0              1        1
# 2  2016-10-18 07:59:50            2          0              1        1
# 3  2016-10-18 07:32:33            3          0              1        1
# 4  2016-10-18 07:32:46            3          0              1        1
#
#    vehicle_type
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN

# %%
training_path = '../../dataSets/training/'
testing_path = '../../dataSets/testing_phase1/'

# %%
from scripts.pre_processing import merge_file

# %%
training_files_trajectories = {'trajectories_file': 'trajectories(table 5)_training', 'weather_file':'weather (table 7)_training_update'}
training_set = merge_file(training_path, **training_files_trajectories)

# %%
training_set.head(10)
# Out:
#   intersection_id  tollgate_id       starting_time  travel_time  pressure  \
# 0               A            2 2016-07-19 00:20:00        58.05    1000.9
# 1               A            2 2016-07-19 01:20:00        56.87    1000.9
# 2               A            3 2016-07-19 01:20:00        94.57    1000.9
# 3               B            1 2016-07-19 00:20:00        79.76    1000.9
# 4               B            1 2016-07-19 00:40:00       137.98    1000.9
# 5               B            1 2016-07-19 01:20:00       176.70    1000.9
# 6               B            3 2016-07-19 00:00:00        70.85    1000.9
# 7               B            3 2016-07-19 00:20:00       148.79    1000.9
# 8               C            1 2016-07-19 01:20:00       214.87    1000.9
# 9               C            3 2016-07-19 00:40:00       113.54    1000.9
#
#    sea_pressure  wind_direction  wind_speed  temperature  rel_humidity  \
# 0        1005.8           219.0         3.3         27.5          81.0
# ...

# %%
print('Number of records of trajoctories: %d' % len(df_trajectories), '\nNumber of records of volume: %d' % len(df_volume))
# Out:
# Number of records of trajoctories: 109244
# Number of records of volume: 543699

# %%
len(training_set)
# Out:
# 24756

# %%
testing_files_trajectories = {'trajectories_file': 'trajectories(table 5)_test1',
                             'weather_file': 'weather (table 7)_test1'}
testing_set = merge_file(testing_path, **testing_files_trajectories)

# %%
testing_set.head()
# Out:
#   intersection_id  tollgate_id       starting_time  travel_time  pressure  \
# 0               A            2 2016-10-18 06:00:00        41.10    1012.5
# 1               A            2 2016-10-18 06:20:00        43.68    1012.5
# 2               A            2 2016-10-18 06:40:00        68.02    1012.5
# 3               A            2 2016-10-18 07:00:00        52.61    1012.5
# 4               A            2 2016-10-18 07:20:00        56.17    1012.5
#
#    sea_pressure  wind_direction  wind_speed  temperature  rel_humidity  \
# 0        1017.5           128.0         1.6         23.4          73.0
# 1        1017.5           128.0         1.6         23.4          73.0
# 2        1017.5           128.0         1.6         23.4          73.0
# 3        1017.5           128.0         1.6         23.4          73.0
# 4        1017.5           128.0         1.6         23.4          73.0
#
#    precipitation week  hour  minute
# 0            0.0    2     6       0
# ...

# %%
len(testing_set)
# Out:
# 448

# %%
training_set_big = training_set.append(testing_set)

# %%
len(training_set_big)
# Out:
# 25204

# %%
training_set_big.to_csv(training_path + 'training.csv', index=False)
